# %%
class Node:

    def __init__(self, key, value):
        self.value = value
        self.key = key
        self.next = None
        self.prev = None
        
class DoubleLinkedList:
    def __init__(self):
        
        self.head = None
        self.tail = None
        
    def add(self,node):
        # for double linkied list
        # first case if data strc is empty 
        if(self.head is None):
            
            self.head=node
            self.tail=self.head
        else: # second case if double linkied not empty
            
            self.tail.next = node
            self.tail.next.prev = self.tail
            self.tail = self.tail.next
        return self.tail

    def popItem(self):
        lastone = self.tail.key
        
        if self.tail == self.head:
            
            self.head = None
            self.tail = None
            return lastone
        self.tail.prev.next = None
        self.tail = self.tail.prev
        return lastone

        
        
        
        
        
class LRU_Cache(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.dict = {}
        self.dblist = DoubleLinkedList()
        pass

    def get(self, key):
        if key is None or key=="" or key not in self.dict:
            return -1
        
        Node = self.dict[key]
        self.dblist.add(Node)
        return Node
        
        pass

    def set(self, key, value):
        if self.capacity <= 0:
            return
        x=len(self.dict)
        if x == self.capacity:
            
            self.dict.popItem()

        self.dict[key] = value
        pass

our_cache = LRU_Cache(5)

our_cache.set(1, 1);
our_cache.set(2, 2);
our_cache.set(3, 3);
our_cache.set(4, 4);


our_cache.get(1)       # returns 1
our_cache.get(2)       # returns 2
our_cache.get(9)      # returns -1 because 9 is not present in the cache

our_cache.set(5, 5) 
our_cache.set(6, 6)

our_cache.get(3)      # returns -1 because the cache reached it's capacity and 3 was the least recently used entry
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-f7b40cf96b3d> in <module>
#      82
#      83 our_cache.get(1)       # returns 1
# ---> 84 our_cache.get(2)       # returns 2
#      85 our_cache.get(9)      # returns -1 because 9 is not present in the cache
#      86
#
# <ipython-input-1-f7b40cf96b3d> in get(self, key)
#      57
#      58         Node = self.dict[key]
# ---> 59         self.dblist.add(Node)
#      60         return Node
#      61
#
# <ipython-input-1-f7b40cf96b3d> in add(self, node)
#      22         else: # second case if double linkied not empty
#      23
# ---> 24             self.tail.next = node
#      25             self.tail.next.prev = self.tail
#      26             self.tail = self.tail.next
#
# AttributeError: 'int' object has no attribute 'next'

# %%
nxwaf
